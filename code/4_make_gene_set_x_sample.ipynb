# %%
# %load_ext autoreload
# %autoreload 2

# %%
from environment import *

with open("setting.yaml") as yaml_file:

    SETTING = yaml.load(yaml_file)

PATH = make_path_dict(SETTING)

# %%
gene_x_sample = pd.read_csv(PATH["gene_x_sample_file_path"], sep="\t", index_col=0)

# %%
gene_set_x_sample = ccal.single_sample_gseas(
    gene_x_sample,
    ccal.read_gmts(PATH["gene_set_file_paths"]),
    n_job=SETTING["n_job"],
    file_path=PATH["gene_set_x_sample_file_path"],
)

gene_set_x_sample
