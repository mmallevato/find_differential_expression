# %%
# %load_ext autoreload
# %autoreload 2

# %%
from environment import *

from parameters import *
# Out:
# CCAL version 0.6.9 @ /Users/k/Jumis/github_ccal/ccal/ccal/__init__.py

# %%
gene_x_sample = pd.read_table('../data/gene_x_sample.tsv', index_col=0)

gene_x_sample
# Out:
#             C_1_tpm    C_2_tpm    C_3_tpm   VS_1_tpm   VS_2_tpm   VS_3_tpm
# A1BG       2.773832   3.061122   3.323683   3.138078   3.319405   3.328272
# A1CF      -4.309364  -4.879056 -20.547961 -20.547961  -4.832995 -20.547961
# A2M        4.388596   4.267691   4.328505   4.382980   4.350769   4.355897
# A2ML1     -3.249245  -3.124780  -3.894222  -3.444419  -2.777175 -20.547961
# A2MP1    -20.547961 -20.547961 -20.547961  -3.474197 -20.547961  -1.628269
# A3GALT2  -20.547961 -20.547961 -20.547961  -2.536979 -20.547961 -20.547961
# A4GALT   -20.547961  -2.711105  -1.485452  -2.842711 -20.547961  -2.208439
# A4GNT     -3.217519 -20.547961  -3.173718 -20.547961  -3.051012 -20.547961
# AAAS       3.448637   3.363447   3.355740   3.434474   3.488307   3.428466
# AACS       1.461137   1.319879   1.481868   1.418142   1.396643   1.416370
# AACSP1   -20.547961  -2.027016 -20.547961  -3.060902 -20.547961  -3.733592
# ...

# %%
target_x_sample = pd.read_table('../data/target_x_sample.tsv', index_col=0)

target_x_sample
# Out:
#                     C_1_tpm  C_2_tpm  C_3_tpm  VS_1_tpm  VS_2_tpm  VS_3_tpm
# Control vs Treated        0        0        0         1         1         1

# %%
make_match_panels(target_x_sample, gene_x_sample, N_JOB, 100, GENES_TO_PEEK,
                  '', '../output/gene')
# Out:
# Control vs Treated
# target.index (6) & features.columns (6) have 6 in common.
# file:///Users/k/Jumis/github_ccal/find_differential_expressions/output/gene/Control vs Treated.match_panel.html
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...
