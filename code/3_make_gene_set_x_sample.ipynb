# %%
# %load_ext autoreload
# %autoreload 2

# %%
from environment import *
from setting import *

# %%
gene_x_sample = pd.read_table(PATH_DICT["gene_x_sample_file_path"], index_col=0)

# %%
gene_set_x_sample = ccal.single_sample_gseas(
    gene_x_sample,
    ccal.read_gmts(PATH_DICT["gene_set_file_paths"]),
    n_job=N_JOB,
    file_path=PATH_DICT["gene_set_x_sample_file_path"],
)

gene_set_x_sample
