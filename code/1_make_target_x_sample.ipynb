# %%
# %load_ext autoreload
# %autoreload 2

# %%
from environment import *
from setting import *

# %%
gene_x_sample = pd.read_table(PATH_DICT["gene_x_sample_file_path"], index_col=0)

# %%
target_x_sample = pd.DataFrame(columns=gene_x_sample.columns)

target_x_sample.index.name = "Target"

target_x_sample.columns.name = "Sample"

target_x_sample.loc["effect"] = (-1,) * 6 + (0,) * 3 + (1,) * 3

target_x_sample.loc["no_effect"] = (0,) * 3 + (1,) * 3 + (-1,) * 6

target_x_sample.to_csv(PATH_DICT["target_x_sample_file_path"], sep="\t")

target_x_sample
